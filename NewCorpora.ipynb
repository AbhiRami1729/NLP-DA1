# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhiRami1729/NLP-DA1/blob/main/NewCorpora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, os.path
  
path = os.path.expanduser('~/nltk_data')

if not os.path.exists(path):
    os.mkdir(path)
      
print ("Does path exists : ", os.path.exists(path))
  
  
import nltk.data
print ("\nDoes path exists in nltk : ", 
       path in nltk.data.path)
# Out:
# Does path exists :  True
#
# Does path exists in nltk :  True

# %%
import nltk.data
abhi=nltk.data.load('abhicorpora.txt', format ='raw')
abhi
# Out:
# b'\r\nI am Abhirami. This is my customized Corpora. This is taken from certain famous literary works in English Literature. Sweet dreams form a shade,\r\nO\'er my lovely infants head.\r\nSweet dreams of pleasant streams,\r\nBy happy silent moony beams\r\n\r\nSweet sleep with soft down.\r\nWeave thy brows an infant crown.\r\nSweet sleep Angel mild,\r\nHover o\'er my happy child.\r\n\r\nSweet smiles in the night,\r\nHover over my delight.\r\nSweet smiles Mothers smiles,\r\nAll the livelong night beguiles.\r\n\r\nSweet moans, dovelike sighs,\r\nChase not slumber from thy eyes,\r\nSweet moans, sweeter smiles,\r\nAll the dovelike moans beguiles.\r\n\r\nSleep sleep happy child,\r\nAll creation slept and smil\'d.\r\nSleep sleep, happy sleep.\r\nWhile o\'er thee thy mother weep\r\n\r\nBassanio, a young Venetian of noble rank, wishes to woo the beautiful and wealthy heiress Portia of Belmont. Having squandered his estate, he needs 3,000 ducats to subsidise his expenditures as a suitor. Bassan
# ...

# %%
f = open('abhicorpora.txt')

# %%
import os
os.listdir('.')
# Out:
# ['.config', 'abhicorpora.txt', 'sample_data']

# %%
abhi = abhi.decode('ISO-8859-1')

# %%
tokens = word_tokenize(abhi)
tokens[:10] #word segmentation
# Out:
# ['I', 'am', 'Abhirami', '.', 'This', 'is', 'my', 'customized', 'Corpora', '.']

# %%
from nltk.tokenize import sent_tokenize
sent_tokenize(abhi) #sentence segmentation
# Out:
# ['\r\ni am abhirami.',
#  'this is my customized corpora.',
#  'this is taken from certain famous literary works in english literature.',
#  "sweet dreams form a shade,\r\no'er my lovely infants head.",
#  'sweet dreams of pleasant streams,\r\nby happy silent moony beams\r\n\r\nsweet sleep with soft down.',
#  'weave thy brows an infant crown.',
#  "sweet sleep angel mild,\r\nhover o'er my happy child.",
#  'sweet smiles in the night,\r\nhover over my delight.',
#  'sweet smiles mothers smiles,\r\nall the livelong night beguiles.',
#  'sweet moans, dovelike sighs,\r\nchase not slumber from thy eyes,\r\nsweet moans, sweeter smiles,\r\nall the dovelike moans beguiles.',
#  "sleep sleep happy child,\r\nall creation slept and smil'd.",
#  'sleep sleep, happy sleep.',
#  "while o'er thee thy mother weep\r\n\r\nbassanio, a young venetian of noble rank, wishes to woo the beautiful and wealthy heiress portia of belmont.",
# ...

# %%
abhi=abhi.lower()
abhi #conversion to lowercase
# Out:
# '\r\ni am abhirami. this is my customized corpora. this is taken from certain famous literary works in english literature. sweet dreams form a shade,\r\no\'er my lovely infants head.\r\nsweet dreams of pleasant streams,\r\nby happy silent moony beams\r\n\r\nsweet sleep with soft down.\r\nweave thy brows an infant crown.\r\nsweet sleep angel mild,\r\nhover o\'er my happy child.\r\n\r\nsweet smiles in the night,\r\nhover over my delight.\r\nsweet smiles mothers smiles,\r\nall the livelong night beguiles.\r\n\r\nsweet moans, dovelike sighs,\r\nchase not slumber from thy eyes,\r\nsweet moans, sweeter smiles,\r\nall the dovelike moans beguiles.\r\n\r\nsleep sleep happy child,\r\nall creation slept and smil\'d.\r\nsleep sleep, happy sleep.\r\nwhile o\'er thee thy mother weep\r\n\r\nbassanio, a young venetian of noble rank, wishes to woo the beautiful and wealthy heiress portia of belmont. having squandered his estate, he needs 3,000 ducats to subsidise his expenditures as a suitor. bassani
# ...

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(abhi)

filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
filtered_sentence = []
  
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

print(filtered_sentence) #stop words removal
# Out:
# ['abhirami', '.', 'customized', 'corpora', '.', 'taken', 'certain', 'famous', 'literary', 'works', 'english', 'literature', '.', 'sweet', 'dreams', 'form', 'shade', ',', "o'er", 'lovely', 'infants', 'head', '.', 'sweet', 'dreams', 'pleasant', 'streams', ',', 'happy', 'silent', 'moony', 'beams', 'sweet', 'sleep', 'soft', '.', 'weave', 'thy', 'brows', 'infant', 'crown', '.', 'sweet', 'sleep', 'angel', 'mild', ',', 'hover', "o'er", 'happy', 'child', '.', 'sweet', 'smiles', 'night', ',', 'hover', 'delight', '.', 'sweet', 'smiles', 'mothers', 'smiles', ',', 'livelong', 'night', 'beguiles', '.', 'sweet', 'moans', ',', 'dovelike', 'sighs', ',', 'chase', 'slumber', 'thy', 'eyes', ',', 'sweet', 'moans', ',', 'sweeter', 'smiles', ',', 'dovelike', 'moans', 'beguiles', '.', 'sleep', 'sleep', 'happy', 'child', ',', 'creation', 'slept', 'smil', "'d", '.', 'sleep', 'sleep', ',', 'happy', 'sleep', '.', "o'er", 'thee', 'thy', 'mother', 'weep', 'bassanio', ',', 'young', 'venetian', 'noble', 'rank', ',
# ...

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
  
ps = PorterStemmer()
words = word_tokenize(abhi)
  
for w in abhi:
    print(w, " : ", ps.stem(w)) #stemming
# Out:
# Streaming output truncated to the last 5000 lines.
#    :
# d  :  d
# o  :  o
# v  :  v
# e  :  e
# l  :  l
# i  :  i
# k  :  k
# e  :  e
#    :
# s  :  s
# i  :  i
# g  :  g
# h  :  h
# s  :  s
# ,  :  ,
#   :
#
#   :
#
# c  :  c
# h  :  h
# a  :  a
# s  :  s
# e  :  e
#    :
# n  :  n
# o  :  o
# t  :  t
#    :
# s  :  s
# l  :  l
# u  :  u
# m  :  m
# b  :  b
# e  :  e
# r  :  r
#    :
# f  :  f
# r  :  r
# o  :  o
# m  :  m
#    :
# t  :  t
# h  :  h
# y  :  y
#    :
# e  :  e
# y  :  y
# e  :  e
# s  :  s
# ,  :  ,
#   :
#
#   :
#
# s  :  s
# w  :  w
# e  :  e
# e  :  e
# t  :  t
#    :
# m  :  m
# o  :  o
# a  :  a
# n  :  n
# s  :  s
# ,  :  ,
#    :
# s  :  s
# w  :  w
# e  :  e
# e  :  e
# t  :  t
# e  :  e
# r  :  r
#    :
# s  :  s
# m  :  m
# i  :  i
# l  :  l
# e  :  e
# s  :  s
# ,  :  ,
#   :
#
#   :
#
# a  :  a
# l  :  l
# l  :  l
#    :
# t  :  t
# h  :  h
# e  :  e
#    :
# d  :  d
# o  :  o
# v  :  v
# e  :  e
# l  :  l
# i  :  i
# k  :  k
# e  :  e
#    :
# ...

# %%
nltk.download('omw-1.4')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
  
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize(abhi)) #lemmatization
# Out:
# i am abhirami. this is my customized corpora. this is taken from certain famous literary works in english literature. sweet dreams form a shade,
# o'er my lovely infants head.
# sweet dreams of pleasant streams,
# by happy silent moony beams
#
# sweet sleep with soft down.
# weave thy brows an infant crown.
# sweet sleep angel mild,
# hover o'er my happy child.
#
# sweet smiles in the night,
# hover over my delight.
# sweet smiles mothers smiles,
# all the livelong night beguiles.
#
# sweet moans, dovelike sighs,
# chase not slumber from thy eyes,
# sweet moans, sweeter smiles,
# all the dovelike moans beguiles.
#
# sleep sleep happy child,
# all creation slept and smil'd.
# sleep sleep, happy sleep.
# while o'er thee thy mother weep
#
# ...

# %%
from nltk import pos_tag
from nltk import RegexpParser
nltk.download('averaged_perceptron_tagger')
text = tokens
print("After Split:",text)
tokens_tag = pos_tag(text)
print("After Token:",tokens_tag)
patterns= """mychunk:{<NN.?>*<VBD.?>*<JJ.?>*<CC>?}"""
chunker = RegexpParser(patterns)
print("After Regex:",chunker)
output = chunker.parse(tokens_tag)
print("After Chunking",output)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# ...
